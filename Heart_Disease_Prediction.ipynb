# %% [markdown]
# # Pre Processing the Dataset

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("heart_disease.csv")
df
# Out:
#       Gender  age      education  currentSmoker  cigsPerDay  BPMeds  \
# 0       Male   39   postgraduate              0         0.0     0.0
# 1     Female   46  primaryschool              0         0.0     0.0
# 2       Male   48     uneducated              1        20.0     0.0
# 3     Female   61       graduate              1        30.0     0.0
# 4     Female   46       graduate              1        23.0     0.0
# ...      ...  ...            ...            ...         ...     ...
# 4233    Male   50     uneducated              1         1.0     0.0
# 4234    Male   51       graduate              1        43.0     0.0
# 4235  Female   48  primaryschool              1        20.0     NaN
# 4236  Female   44     uneducated              1        15.0     0.0
# 4237  Female   52  primaryschool              0         0.0     0.0
#
#      prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# ...

# %%
df.drop("education", axis=1, inplace=True)

# %%
df
# Out:
#       Gender  age  currentSmoker  cigsPerDay  BPMeds prevalentStroke  \
# 0       Male   39              0         0.0     0.0              no
# 1     Female   46              0         0.0     0.0              no
# 2       Male   48              1        20.0     0.0              no
# 3     Female   61              1        30.0     0.0              no
# 4     Female   46              1        23.0     0.0              no
# ...      ...  ...            ...         ...     ...             ...
# 4233    Male   50              1         1.0     0.0              no
# 4234    Male   51              1        43.0     0.0              no
# 4235  Female   48              1        20.0     NaN              no
# 4236  Female   44              1        15.0     0.0              no
# 4237  Female   52              0         0.0     0.0              no
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#       Gender  age  currentSmoker  cigsPerDay  BPMeds prevalentStroke  \
# 0       Male   39              0         0.0     0.0              no
# 1     Female   46              0         0.0     0.0              no
# 2       Male   48              1        20.0     0.0              no
# 3     Female   61              1        30.0     0.0              no
# 4     Female   46              1        23.0     0.0              no
# ...      ...  ...            ...         ...     ...             ...
# 4231    Male   58              0         0.0     0.0              no
# 4232    Male   68              0         0.0     0.0              no
# 4233    Male   50              1         1.0     0.0              no
# 4234    Male   51              1        43.0     0.0              no
# 4237  Female   52              0         0.0     0.0              no
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# ...

# %%
df["Gender"] = df["Gender"].map({"Male":1, "Female":0}).astype("int")
df["prevalentStroke"] = df["prevalentStroke"].map({"yes":1, "no":0}).astype("int")

# %%
df
# Out:
#       Gender  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0          1   39              0         0.0     0.0                0
# 1          0   46              0         0.0     0.0                0
# 2          1   48              1        20.0     0.0                0
# 3          0   61              1        30.0     0.0                0
# 4          0   46              1        23.0     0.0                0
# ...      ...  ...            ...         ...     ...              ...
# 4231       1   58              0         0.0     0.0                0
# 4232       1   68              0         0.0     0.0                0
# 4233       1   50              1         1.0     0.0                0
# 4234       1   51              1        43.0     0.0                0
# 4237       0   52              0         0.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# ...

# %%
df["Heart_ stroke"] = df["Heart_ stroke"].map({"yes":1, "No":0}).astype("int")

# %%
df
# Out:
#       Gender  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0          1   39              0         0.0     0.0                0
# 1          0   46              0         0.0     0.0                0
# 2          1   48              1        20.0     0.0                0
# 3          0   61              1        30.0     0.0                0
# 4          0   46              1        23.0     0.0                0
# ...      ...  ...            ...         ...     ...              ...
# 4231       1   58              0         0.0     0.0                0
# 4232       1   68              0         0.0     0.0                0
# 4233       1   50              1         1.0     0.0                0
# 4234       1   51              1        43.0     0.0                0
# 4237       0   52              0         0.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# ...

# %% [markdown]
# # Store Feature Matrix in X and Traget in Vector y

# %%
X = df.drop("Heart_ stroke", axis=1)
y = df["Heart_ stroke"]

# %%
y.value_counts()
# Out:
# Heart_ stroke
# 0    3177
# 1     572
# Name: count, dtype: int64

# %% [markdown]
# # Data Resampling

# %%
pip install --upgrade scikit-learn imbalanced-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE(random_state=2)

# %%
X,y = sm.fit_resample(X, y.ravel())

# %%
np.unique(y, return_counts=True)
# Out:
# (array([0, 1]), array([3177, 3177], dtype=int64))

# %% [markdown]
# # Model Creation

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# C:\Users\yhima\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.score(X_test, y_test)
# Out:
# 0.6483084185680567

# %% [markdown]
# # Predicting Values from Model

# %%
input = np.array([[0,59,0,0,0,0,1,0,209,150,85,20.77,90,88]])

# %%
x = model.predict(input)
x[0]
# Out:
# C:\Users\yhima\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# 1

# %%
import pickle as pk

# %%
pk.dump(model, open("Heart_disease_model.pkl", "wb"))

# %% [markdown]
# # Deploying model as Web App

# %% [markdown]
# ## In the Visual Studio Code
